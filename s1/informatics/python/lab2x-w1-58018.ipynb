# %% [markdown]
# ## Zadanie
#
# Utwórz string `s1` będący powtórzeniem Twojego imienia i nazwiska tyle razy ile wynosi reszta z dzielenia wartości Twojego numeru indeksu przez `99` (jeśli reszta wynosi `0`, to znajdź resztę z dzielenia przez `999`)
#
#
# ```
# przykład:
# nr_indeksu, imie, nazwisko = 99003, 'Błażej', 'Kuś'
# s1: BłażejKuśBłażejKuśBłażejKuś
# ```
#
# Napisz funkcję `f1` przyjmującą jako argument `s1` i zwracającą dwie listy:
# `x` - lista zawierająca co trzecią literę z `s1` od początku
# `y` - lista zawierająca co trzecią literę z `s1` od końca
#
# uwaga: `(type(x): <class 'list'>)`, `(type(y): <class 'list'>)`
#
#
# ```
# przykład:
# x: ['B', 'ż', 'K', 'B', 'ż', 'K', 'B', 'ż', 'K']
# y: ['ś', 'j', 'a', 'ś', 'j', 'a', 'ś', 'j', 'a']
# ```
#
# Następnie utwórz listę `z` zawierającą elementy z `x` i `y` będące znakami ASCII (kod <= 127)
#
# **znajdź:**
# `w1`, będące sumą wszystkich znaków z listy `z` (sumą ich kodów)

# %%
nr_indeksu, imie, nazwisko = 155197, "REDACTED", "REDACTED"

repetition = nr_indeksu % 99
if repetition == 0:
	repetition = nr_indeksu % 999

s1 = (imie + nazwisko) * repetition
print("s1:", s1)
# Out:
# s1: ...

# %%
def f1(s1):
	x = list(s1[0::3])
	y = list(s1[::-3])
	return x, y

x, y = f1(s1)
print("x:", x)
print("y:", y)

z = [char for char in (x + y) if ord(char) <= 127]
print("z:", z)

w1 = sum(ord(char) for char in z)
print("w1:", w1)

nazwa_notebooka = f'lab2x___w1_{w1}.ipynb'
print(f'nazwa_notebooka: {nazwa_notebooka}')
# Out:
# x: ['M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a']
# y: ['a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M']
# z: ['M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 't', 's', 'a', 't', 'a', 'u', 'L', 'o', 'M', 'e', 'z', 's', 'a', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M', 'o', 'L', 'u', 'a', 't', 'a', 's', 't', 'a', 's', 'z', 'e', 'M']
# w1: 58018
# nazwa_notebooka: lab2x-w1-58018.ipynb
